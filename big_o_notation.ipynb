# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = range(-100, 100)

y1 = [n + 1  for n in x]

y2 = [np.log(n) for n in x]

y3 = [n for n in x]

y4 = [(np.log(n) * n) for n in x]

y5 = []





plt.figure(figsize = (20, 9))

y = [n for n in x ]


plt.plot(x,y1, c='r')
plt.plot(x, y2)
plt.plot(x, y3, c='g')
plt.plot(x, y4)

plt.title('Big O Notation', c='orange')
plt.xlabel('$Elements$', c='g')
plt.ylabel('$Operations$', c='g')

plt.legend(loc='upper right')
# Out:
# /var/folders/b2/3fdswr7x4v5fhdt54wpcfmdw0000gn/T/ipykernel_17725/786029165.py:5: RuntimeWarning: invalid value encountered in log
#   y2 = [np.log(n) for n in x]
# /var/folders/b2/3fdswr7x4v5fhdt54wpcfmdw0000gn/T/ipykernel_17725/786029165.py:5: RuntimeWarning: divide by zero encountered in log
#   y2 = [np.log(n) for n in x]
# /var/folders/b2/3fdswr7x4v5fhdt54wpcfmdw0000gn/T/ipykernel_17725/786029165.py:9: RuntimeWarning: invalid value encountered in log
#   y4 = [(np.log(n) * n) for n in x]
# /var/folders/b2/3fdswr7x4v5fhdt54wpcfmdw0000gn/T/ipykernel_17725/786029165.py:9: RuntimeWarning: divide by zero encountered in log
#   y4 = [(np.log(n) * n) for n in x]
# /var/folders/b2/3fdswr7x4v5fhdt54wpcfmdw0000gn/T/ipykernel_17725/786029165.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   y4 = [(np.log(n) * n) for n in x]
# No handles with labels found to put in legend.
